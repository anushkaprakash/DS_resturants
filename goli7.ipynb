# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pricing = pd.read_csv("/Users/anushka/Desktop/Decision Science - Intern/Market Pricing.csv")
pricing.head()
# Out:
#   Restaurant   Menu Header                  Menu Item Rate  \
# 0       12 e  Veg Starters               Paneer Tikka  190
# 1       12 e  Veg Starters     Paneer Peshawari Tikka  200
# 2       12 e  Veg Starters     Paneer Kalimirch Tikka  190
# 3       12 e  Veg Starters         Paneer Malai Tikka  200
# 4       12 e  Veg Starters  Cheese Chilly Onion Kabah  160
#
#              What people love here
# 0  Butter Chicken, Chicken Biryani
# 1  Butter Chicken, Chicken Biryani
# 2  Butter Chicken, Chicken Biryani
# 3  Butter Chicken, Chicken Biryani
# 4  Butter Chicken, Chicken Biryani

# %%
pricing.drop_duplicates(['What people love here'],inplace=True)
pricing.drop(labels = ['Restaurant','Menu Header','Menu Item','Rate'],axis=1,inplace=True)
pricing.dropna(inplace=True)
pricing.head()
# Out:
#                                  What people love here
# 0                      Butter Chicken, Chicken Biryani
# 76                                          Fish Tikka
# 485                            Paneer Tikka, Dal Tadka
# 603                 Gulab Jamun, Rice, Chicken Biryani
# 691  Shawarma, Chicken Taka Tak, Barbeque Chicken, ...

# %%
dishes = []
for i in pricing.index:
    dishes += pricing.loc[i,'What people love here'].split(',')
dishes.sort()
dishes = [i.strip() for i in dishes]
unique_dishes = set(dishes)

dict1 = {}
for i in unique_dishes:
    dict1[i] = dishes.count(i)
dict1
# Out:
# {'Afghan Chicken': 1,
#  'Barbeque Chicken': 1,
#  'Biryani': 2,
#  'Boti Chicken': 1,
#  'Butter Chicken': 11,
#  'Butter Naan': 1,
#  'Chicken Biryani': 6,
#  'Chicken Dum Biryani': 1,
#  'Chicken Grill': 1,
#  'Chicken Lollipop': 1,
#  'Chicken Malai Tikka': 1,
#  'Chicken Roll': 1,
#  'Chicken Shawarama': 1,
#  'Chicken Sukha': 1,
#  'Chicken Taka Tak': 1,
#  'Chicken Tariwala': 1,
#  'Chicken Tenders': 1,
#  'Chicken Tikka': 5,
#  'Chicken Tikka Biryani': 1,
#  'Chicken Tikka Masala': 1,
#  'Crispy Corn': 1,
#  'Dahi Kebab': 1,
#  'Dal Makhani': 4,
#  'Dal Tadka': 1,
#  'Dum Biryani': 2,
#  'Egg Curry': 1,
#  'Fish': 2,
#  'Fish Tikka': 2,
#  'Gulab Jamun': 2,
#  'Haleem': 1,
#  'Hyderabadi Biryani': 1,
#  'Hyderabadi Chicken': 1,
#  'Jumbo Prawns': 1,
#  'Keema Kaleji': 1,
#  'Kiwi Mojito': 1,
#  'Lassi': 1,
#  'Malai Kofta': 1,
#  'Manchow Soup': 1,
#  'Mint Mojito': 1,
#  'Mutton Bhuna': 1,
#  'Mutton Biryani': 2,
#  'Mutton Curry': 1,
#  'Mutton Rara': 1,
#  'Naan': 4,
#  'Nalli Nihari': 1,
#  'Paan Ice Cream': 1,
#  'Paneer Makhani': 1,
#  'Paneer Tikka': 1,
#  'Paneer Tikka Masala': 2,
#  'Panneer Butter Masala': 2,
#  'Raita': 1,
#  'Rice': 5,
#  'Rolls': 1,
#  'Roti': 1,
#  'Rumali Roti': 3,
#  'Salad': 1,
#  'Salads': 1,
#  'Seekh Kebab': 1,
#  'Shawarma': 2,
#  'Tandoori Chicken': 9,
#  'Vegetable Biryani': 1}

# %%
plt.figure()
index = np.arange(len(dict1))
plt.bar(index,list(dict1.values()))
plt.xlabel('Dishes', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(index, dict1.keys(), fontsize=5,rotation=90)
plt.title('Popularity of dishes')
plt.show()

# %%
df = pd.DataFrame.from_dict(dict1, orient = 'index' )
df.columns = ['Count']
df.head()
# Out:
#                  Count
# Chicken Biryani      6
# Haleem               1
# Biryani              2
# Roti                 1
# Nalli Nihari         1

# %%
df.sort_values('Count',inplace=True,ascending=False)
df[:20]
# Out:
#                        Count
# Butter Chicken            11
# Tandoori Chicken           9
# Chicken Biryani            6
# Chicken Tikka              5
# Rice                       5
# Naan                       4
# Dal Makhani                4
# Rumali Roti                3
# Paneer Tikka Masala        2
# Gulab Jamun                2
# Fish Tikka                 2
# Shawarma                   2
# Dum Biryani                2
# Mutton Biryani             2
# Biryani                    2
# Fish                       2
# Panneer Butter Masala      2
# Boti Chicken               1
# Vegetable Biryani          1
# Paan Ice Cream             1
