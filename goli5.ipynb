# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bill = pd.read_csv("/Users/anushka/Desktop/Decision Science - Intern/Customer Bill Detail.csv")
bill.head()

bill.drop(labels = ['Type','Date','Bill Number','Discount','Subtotal','Delivery Amt','Channel','Customer ID'], axis=1, inplace=True)
bill.head()
# Out:
#    Total Bill                                       Dish Details
# 0         500  Tandoori Roti (QTY-1.000),Tandoori Roti (QTY-1...
# 1         450  Tomato Soup (QTY-1.000),Masala Cheese Maggi (Q...
# 2         150  Lachchha Paratha (QTY-1.000),Chicken Nilgir (Q...
# 3         160   Hyderabadi Chicken Fry Piece Biryani (QTY-1.000)
# 4         160          Hyderabadi Mutton Dum Biryani (QTY-1.000)

# %%
df = pd.DataFrame(columns = ['Dish Combo','Count','Cost'])
for i in bill.index:
    a = bill.loc[i,'Dish Details']
    a = a.split(',')
    a = [i.split(' (')[0] for i in a]
    a = set(a)
    a = list(a)
    if len(a)>1:
        flag = 0
        j = 0
        tt = 0
        for j in df.index:
            flag = 0
            temp = df.loc[j,'Dish Combo']
            if len(a) == len(temp):
                for k in range(len(a)):
                    if a[k]!=temp[k]:
                        flag = 1
                if flag == 0:
                    tt = j
                    break
            else:
                flag = 1
        if flag == 1 or i==0:
            df = df.append({'Dish Combo':a,'Count':1,'Cost':bill.loc[i,'Total Bill']}, ignore_index=True)
        else:
            df.loc[tt,'Count'] +=1

# %%
df.sort_values('Count',inplace=True,ascending=False)
df['Cost'] = df['Cost']-0.05*df['Cost']
df
# Out:
#                                              Dish Combo Count    Cost
# 60                       [Tandoori Roti, Chicken Curry]   127   205.2
# 15                      [Tandoori Roti, Butter Chicken]    62   193.8
# 106                          [Tandoori Roti, Egg Curry]    44   140.6
# 70                [Tandoori Roti Butter, Chicken Curry]    43  213.75
# 378              [Butter Chicken, Tandoori Roti Butter]    36   256.5
# 176                     [Tandoori Roti, Kadhai Chicken]    33   277.4
# 232   [Hyderabadi Chicken Fry Piece Biryani, Hyderab...    26     456
# 353                   [Egg Curry, Tandoori Roti Butter]    24     152
# 249                      [Tandoori Roti, Chicken Handi]    23   186.2
# 38                  [Tandoori Roti, Chicken Home Style]    23   169.1
# 542                        [Butter Chicken, Butter nan]    17   218.5
# 411                         [Chicken Curry, Butter nan]    16  185.25
# 398   [Tandoori Chicken, Hyderabadi Mutton Dum Biryani]    15     304
# 177   [Tandoori Roti, Hyderabadi Chicken Fry Piece B...    15   288.8
# 381   [Hyderabadi Chicken Fry Piece Biryani, Veg Bir...    15   294.5
# 1065                       [Tandoori Roti, Sev Tamater]    14     209
# 380          [Tandoori Roti, Chicken Curry, Plain Rice]    13   387.6
# 262                     [Tandoori Roti, Chilly Chicken]    13   188.1
# 682                  [Tandoori Roti, Mutton Rogan Josh]    13   176.7
# 341   [Tandoori Chicken, Hyderabadi Chicken Fry Piec...    12     304
